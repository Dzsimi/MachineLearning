# %% [markdown]
# # Loading packages

# %%
import pandas as pd
import os
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import altair as alt
import numpy as np
from sklearn.cluster import DBSCAN, HDBSCAN
from umap import UMAP
import fasttext
import fasttext.util

# %% [markdown]
# # Looping through the dataframes, creating label dummies and text vectors.
# ### You can jump to the 'Clustering' part and use the corresponding merged dataframe

# %%
strings_to_check = ['Belföld', 'Külföld', 'Gazdaság', 'Életmód', 'Sport', 'Techtud', 'After', 'English']

# Function to construct binary variables
def construct_binary_variables(row):
    binary_vars = []
    for string in strings_to_check:
        if string in row.values:
            binary_vars.append(1)
        else:
            binary_vars.append(0)
    return binary_vars

# model = SentenceTransformer("all-mpnet-base-v2")

fasttext.util.download_model('hu', if_exists='ignore')
model = fasttext.load_model('cc.hu.300.bin')

# %% [markdown]
# #### Using Facebook's text vectorizer, trained on Hungarian text, I add the semantic vector of each text while also adding the label dummies.

# %%
# "C:/Users/imre2/Desktop/Telex scrape/EDA" contains the raw scraped files
folder_path = "C:/Users/imre2/Desktop/Telex scrape/EDA"

# Looping through the downloaded files
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        
        # Reading the CSV file
        df = pd.read_csv(file_path)
        
        #################
        # Creating the tag binary variables and attaching them to the dataframe
        binary_df = pd.DataFrame(df.apply(construct_binary_variables, axis=1).tolist(), columns=strings_to_check)
        df = pd.concat([df, binary_df], axis=1)
        
        # Creating the 300 new variables
        na_columns = pd.DataFrame(np.nan, index=df.index, columns=[f'new_var_{i+1}' for i in range(300)])
        df = pd.concat([df, na_columns], axis=1)

        # Dropping those observations for which text is empty (somehow it happened when text is structured in bullet points)
        df = df.dropna(subset=['texts'])

        # Creating the text vectors and attaching them to the datafarme
        for row_index in df.index:
            text_temp = df['texts'][row_index]
            word_vectors = [model.get_word_vector(word) for word in text_temp.split()]
            document_vector = sum(word_vectors) / len(word_vectors)
            df.loc[row_index, [f'new_var_{i+1}' for i in range(300)]] = document_vector
        
        # Dropping empty observations (in some article structures like bullet points only, I got no text)
        df = df.dropna(subset=['texts'])
        #################
        
        # Saving the updated dataframe
        df.to_csv(file_path, index=False)
        
        # Easy check
        print(file_path)
# Out:
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_after_91_100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1001_1010.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1011_1020.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1021_1030.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1031_1040.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1041_1050.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1051_1060.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1061_1070.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1071_1080.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1081_1090.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1091_1100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1101_1110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1111_1120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1121_1130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1131_1140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1141_1150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1151_1160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1161_1170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1171_1180.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1181_1190.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_171_180.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_181_190.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_191_200.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_201_210.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_211_220.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_221_230.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_231_240.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_241_250.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_251_260.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_261_270.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_271_280.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_281_290.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_291_300.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_301_310.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_311_320.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_321_330.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_331_340.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_341_350.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_351_360.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_361_370.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_371_380.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_381_390.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_391_400.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_401_410.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_411_420.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_421_430.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_431_440.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_441_450.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_451_460.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_461_470.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_471_480.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_481_490.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_491_500.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_501_510.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_511_520.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_521_530.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_531_540.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_541_550.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_551_560.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_561_570.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_571_580.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_581_590.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_591_600.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_601_610.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_611_620.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_621_630.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_631_640.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_641_650.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_651_660.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_661_670.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_671_680.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_681_690.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_691_700.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_701_710.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_711_720.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_721_730.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_731_740.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_741_750.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_751_760.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_761_770.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_771_780.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_781_790.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_791_800.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_801_810.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_811_820.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_821_830.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_831_840.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_841_850.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_851_860.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_861_870.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_871_880.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_881_890.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_891_900.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_901_910.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_911_920.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_91_100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_921_930.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_931_940.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_941_950.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_951_960.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_961_970.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_971_980.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_981_990.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_belfold_991_1000.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_eletmod_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_eletmod_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_eletmod_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_english_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_171_180.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_181_190.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_191_200.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_201_210.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_211_220.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_221_230.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_231_240.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_241_250.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_251_260.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_gazdasag_91_100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_171_180.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_181_190.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_191_200.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_201_210.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_211_220.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_221_230.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_231_240.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_241_250.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_251_260.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_261_270.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_271_280.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_281_290.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_291_300.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_301_310.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_311_320.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_321_330.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_331_340.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_341_350.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_351_360.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_361_370.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_371_380.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_381_390.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_391_400.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_401_410.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_411_420.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_421_430.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_431_440.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_441_450.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_451_460.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_461_470.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_471_480.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_481_490.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_491_500.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_501_510.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_511_520.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_521_530.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_531_540.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_541_550.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_551_560.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_561_570.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_571_580.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_581_590.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_591_600.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_601_610.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_611_620.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_621_630.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_631_640.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_641_650.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_651_660.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_661_670.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_671_680.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_kulfold_91_100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_171_180.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_181_190.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_191_200.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_201_210.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_211_220.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_221_230.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_sport_91_100.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_101_110.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_111_120.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_11_20.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_121_130.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_131_140.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_141_150.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_151_160.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_161_170.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_1_10.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_21_30.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_31_40.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_41_50.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_51_60.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_61_70.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_71_80.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_81_90.csv
# C:/Users/imre2/Desktop/Telex scrape/EDA\telex_techtud_91_100.csv

# %% [markdown]
# # Merging data

# %% [markdown]
# #### I merge the previously transformed files into a single dataframe and save it.

# %%
# "C:/Users/imre2/Desktop/Telex scrape/EDA" contains the transformed dataframes.
folder_path = "C:/Users/imre2/Desktop/Telex scrape/EDA"

# List to hold DataFrames
df_list = []

# Iterate through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Append the DataFrame to the list
        df_list.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
merged_df = pd.concat(df_list, ignore_index=True)

merged_df = merged_df.drop_duplicates()

# merged_df.to_csv('C:/Users/imre2/Desktop/merged_df.csv', index=False)

# %%
merged_df[:5]
# Out:
#                                                 link  \
# 0  https://telex.hu/after/2024/04/17/metallica-ja...
# 1  https://telex.hu/after/2024/04/17/szaz-ev-maga...
# 2  https://telex.hu/after/2024/04/17/the-jesus-an...
# 3  https://telex.hu/after/2024/04/17/civil-war-po...
# 4  https://telex.hu/after/2024/04/17/solo-levelin...
#
#                                               titles      author_primary  \
# 0  A Metallica frontembere beletetováltatta a köz...     Flachner Balázs
# 1  Sorozat készül a Száz év magányból, íme az els...  Aradi Hanga Zsófia
# 2  A The Jesus and Mary Chain lesz a Fekete Zaj i...        Antal Bálint
# 3        Ez itt Amerika, ahol mindenki lő mindenkire          Klág Dávid
# 4  A Solo Leveling egy videójátékozó kamasz leghő...     Flachner Balázs
#
#   author_secondary author_tertary author_quaternary tag_primary tag_secondary  \
# 0              NaN            NaN               NaN       After           NaN
# 1              NaN            NaN               NaN       After           NaN
# 2              NaN            NaN               NaN       After           NaN
# 3              NaN            NaN               NaN       After           NaN
# 4              NaN            NaN               NaN       After           NaN
#
#    tag_tertary  tag_quaternary  ... new_var_291  new_var_292  new_var_293  \
# 0          NaN             NaN  ...    0.005884    -0.016356     0.007988
# 1          NaN             NaN  ...    0.004624    -0.016638     0.000857
# 2          NaN             NaN  ...   -0.003449    -0.014265    -0.000970
# 3          NaN             NaN  ...    0.003370    -0.013774     0.011666
# 4          NaN             NaN  ...   -0.002676    -0.016609     0.007020
#
#    new_var_294  new_var_295  new_var_296  new_var_297  new_var_298  \
# 0    -0.002342    -0.014909    -0.007685     0.012723    -0.006079
# 1    -0.026097    -0.007956    -0.008374     0.012485    -0.003489
# 2    -0.020453    -0.007297    -0.008354     0.014147    -0.009913
# 3    -0.014706    -0.003868    -0.001861     0.010073    -0.006801
# 4    -0.013395    -0.013368    -0.002592     0.015698    -0.005223
#
#    new_var_299  new_var_300
# 0     0.004763    -0.010547
# 1     0.009972    -0.007612
# 2     0.008008    -0.015921
# 3     0.005774    -0.001692
# 4     0.011538    -0.005716
#
# [5 rows x 328 columns]

# %% [markdown]
# # Clustering

# %% [markdown]
# #### Using the transformend, merged dataframe, I carry out clustering, using DBSCAN and HDBSCAN. These clustering algorithms utilize the semantic vectors (the 300 variables) to establish a 300-dimension space and carry out the clustering accordingly.

# %%
# You should use your own file path

merged_df = pd.read_csv('C:/Users/imre2/Desktop/merged_df.csv')

#merged_df = merged_df[~merged_df['texts'].str.contains('class=', na=False)]
#merged_df = merged_df[~merged_df['texts'].str.contains('https://', na=False)]

# %% [markdown]
# #### DBSCAN

# %%
dbscan = DBSCAN(eps=1, min_samples=100)
db_clusters = dbscan.fit_predict(merged_df.iloc[:, 11:])

# print(clusters.max())
print(db_clusters.max())
# Out:
# 10

# %%
merged_df["db_cluster"] = db_clusters
merged_df["db_cluster"].value_counts()
# Out:
#  2     11033
#  1      6023
#  10     2178
#  7      1853
#  0      1636
#  9      1475
#  6       898
#  3       524
# -1       390
#  5       245
#  4       178
#  8       168
# Name: db_cluster, dtype: int64

# %% [markdown]
# ### HDSBSCAN

# %%
hdbscan = HDBSCAN(min_cluster_size=100,min_samples=15)
hdb_clusters = hdbscan.fit_predict(merged_df.iloc[:, 11:])
hdb_clusters.max()
# Out:
# 11

# %%
merged_df["hdb_cluster"] = hdb_clusters
merged_df["hdb_cluster"].value_counts()
# Out:
#  8     11033
#  7      6023
#  1      2178
#  5      1853
#  10     1642
#  0      1475
#  4       898
#  9       524
#  3       245
#  11      202
# -1       182
#  2       178
#  6       168
# Name: hdb_cluster, dtype: int64

# %% [markdown]
# # Vizualization

# %% [markdown]
# #### Using the results of the clustering procedures, I show that the articles have well-separable semantic vectors. This is supposed to point out that based on the semantic content of the articles, distinct groups can be formed and labelled accordingly.

# %%
umap_fit = UMAP(random_state=0, transform_seed=0, n_jobs=1, n_neighbors=10, min_dist= 0.1)
umap_data = umap_fit.fit_transform(merged_df.iloc[:, 11:])
umap_data = pd.DataFrame(umap_data,columns= ["dim1","dim2"])

# %%
umap_data[-10:]
# Out:
#            dim1       dim2
# 26591 -0.394644  10.876820
# 26592 -0.306833  10.350965
# 26593  0.634955  11.080138
# 26594  0.464329  11.021667
# 26595  0.835587  10.611279
# 26596 -0.321341  10.732587
# 26597 -0.430516  10.047922
# 26598  0.597278  10.947031
# 26599  0.600982  10.856202
# 26600  0.640174  11.036839

# %%
umap_data["db_cluster"] = merged_df["db_cluster"]
umap_data["hdb_cluster"] = merged_df["hdb_cluster"]

# %% [markdown]
# ##

# %%
alt.renderers.enable("mimetype")
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
db_cluster_plot = alt.Chart(umap_data).mark_circle(size=10).encode(
    x="dim1", y="dim2", color="db_cluster:N"
).properties(
    width=600, height=500, title="UMAP Transformed vectors coloured by dbscan cluster labels"
)

# %%
hdb_cluster_plot = alt.Chart(umap_data).mark_circle(size=10).encode(
    x="dim1", y="dim2", color="hdb_cluster:N"
).properties(
    width=600, height=500, title="UMAP Transformed vectors coloured by hdbscan cluster labels"
)

# %%
combined_plot = alt.hconcat(db_cluster_plot,hdb_cluster_plot).configure_title(
    fontSize=16,
    anchor="middle",
).configure_legend(
    strokeColor="white",
    fillColor="#AAAAAA",
    padding=10,
    cornerRadius=10,
    labelFontSize=14,
    titleFontSize=14,
).configure_axis(
    titleFontSize=14, labelFontSize=12
)

combined_plot
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
pip install -U altair_viewer
# Out:
# Requirement already satisfied: altair_viewer in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (0.4.0)
# Requirement already satisfied: altair in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair_viewer) (5.3.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair_viewer) (0.4.1)
# Requirement already satisfied: portpicker in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (1.6.0)
# Requirement already satisfied: tornado in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.2)
# Requirement already satisfied: jinja2 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (4.16.0)
# Requirement already satisfied: numpy in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (1.23.4)
# Requirement already satisfied: packaging in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (21.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (1.5.3)
# Requirement already satisfied: toolz in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from altair->altair_viewer) (4.10.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->altair->altair_viewer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->altair->altair_viewer) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair->altair_viewer) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from packaging->altair->altair_viewer) (3.0.9)
# Requirement already satisfied: psutil in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from portpicker->altair-data-server>=0.4.0->altair_viewer) (5.9.2)
# Requirement already satisfied: six>=1.5 in c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->altair->altair_viewer) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\imre2\appdata\local\programs\python\python310\lib\site-packages)

# %%
import altair_saver as alt_saver

# %%
alt_saver.save(combined_plot, 'combined_plot.png')
# Out:
# ---------------------------------------------------------------------------
# NoMatchingVersions                        Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 alt_saver.save(combined_plot, 'combined_plot.png')
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_saver\_core.py:172, in save(chart, fp, fmt, mode, embed_options, method, suppress_data_warning, **kwargs)
#     169 Saver = _select_saver(method, mode=mode, fmt=fmt, fp=fp)
#     170 saver = Saver(spec, mode=mode, embed_options=embed_options, **kwargs)
# --> 172 return saver.save(fp=fp, fmt=fmt)
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_saver\savers\_saver.py:121, in Saver.save(self, fp, fmt)
#     118 if fmt not in self.valid_formats[self._mode]:
#     119     raise ValueError(f"Got fmt={fmt}; expected one of {self.valid_formats}")
# --> 121 content = self._serialize(fmt, "save")
#     122 if fp is None:
#     123     if isinstance(content, dict):
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_saver\savers\_selenium.py:284, in SeleniumSaver._serialize(self, fmt, content_type)
#     283 def _serialize(self, fmt: str, content_type: str) -> MimebundleContent:
# --> 284     out = self._extract(fmt)
#     285     if fmt == "png":
#     286         assert isinstance(out, str)
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_saver\savers\_selenium.py:237, in SeleniumSaver._extract(self, fmt)
#     232 driver = self._registry.get(self._webdriver, self._driver_timeout)
#     234 if self._offline:
#     235     js_resources = {
#     236         "vega.js": get_bundled_script("vega", self._package_versions["vega"]),
# --> 237         "vega-lite.js": get_bundled_script(
#     238             "vega-lite", self._package_versions["vega-lite"]
#     239         ),
#     240         "vega-embed.js": get_bundled_script(
#     241             "vega-embed", self._package_versions["vega-embed"]
#     242         ),
#     243     }
#     244     html = HTML_TEMPLATE.format(
#     245         vega_url="/vega.js",
#     246         vegalite_url="/vega-lite.js",
#     247         vegaembed_url="/vega-embed.js",
#     248     )
#     249 else:
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_viewer\_scripts.py:40, in get_bundled_script(package, version)
#      36 if package not in listing:
#      37     raise ValueError(
#      38         f"package {package!r} not recognized. Available: {list(listing)}"
#      39     )
# ---> 40 version_str = find_version(version, listing[package])
#      41 path = f"scripts/{package}-{version_str}.js"
#      42 content = pkgutil.get_data("altair_viewer", path)
#
# File c:\Users\imre2\AppData\Local\Programs\Python\Python310\lib\site-packages\altair_viewer\_utils.py:212, in find_version(version, candidates, strict_micro)
#     210 matches = [c for c in cand if v.matches(c)]
#     211 if not matches:
# --> 212     raise NoMatchingVersions(
#     213         f"No matches for version={version!r} among {candidates}.\n"
#     214         "Often this can be fixed by updating altair_viewer:\n"
#     215         "    pip install -U altair_viewer"
#     216     )
#     217 return str(matches[-1])
#
# NoMatchingVersions: No matches for version='5.17.0' among ['4.0.2', '4.8.1', '4.17.0'].
# Often this can be fixed by updating altair_viewer:
#     pip install -U altair_viewer

# %%
merged_df['texts'][712]
umap_data['dim1'][712], umap_data['dim2'][712]
# Out:
# (-5.2061944, -8.898701)

# %%
filtered_df = umap_data[(umap_data['dim1'] >= 4) & (umap_data['dim1'] <= 6) & (umap_data['dim2'] >= 7) & (umap_data['dim2'] <= 10)]

# Step 3: Report the index numbers of the filtered observations
indices = filtered_df.index.tolist()

# %%
merged_df['texts'][1701]
# Out:
# 'Az elmúlt hetekben valósággal záporoztak a geotermikus bejelentések. A kormány központi geotermikus stratégiát hirdetett, amiről meg is tudtunk néhány részletet. A Mol Nyrt. is hangsúlyozta új stratégiájában, hogy geotermikus irányba nyit. Mint a cég fogalmazott, a hagyományos szénhidrogén-termelésen túl karbonsemleges projektekkel erősít, a meglevő kompetenciákra építve geotermikus kutatásba kezd. A Másfélfok think tank pedig egy szakmai fórumot szervezett, ahol azt is megismerhettük, hogy Mádlné Szőnyi Judit hidrogeológus, az MTA doktora, a téma neves hazai kutatója milyen lehetőségeket lát az iparág előtt.<h2>Vágyak és valóság</h2>A geotermikus energia hazai helyzetéről Vigh Péter, a Másfélfok alapítója használt egy találó képet a szervezet beszélgetésén:„bárki is jut a hazai energetika csúcsára, mindenki azzal kezdi, hogy geotermikus nagyhatalom leszünk, majd végül úgy távozik a posztjáról, hogy ebből semmi nem valósult meg.”Sajnos ez tényleg így szokott történni, pedig az adottságaink – bár nem vagyunk Izland – európai összehasonlításban is nagyon kedvezőek. Ha pedig 2027-től a Vízkeret irányelv alapján kötelezővé válik a visszasajtolás is, akkor már valóban megújulónak, fenntarthatónak is nevezhetjük majd a hazai geotermiát.Igaz, a mezőgazdaság vagy a fürdők (amelyekkel a balneológia tudománya foglalkozik) megszokták, hogy csak kiveszik, és nem termelik vissza a meleg föld alatti vizeket, így ennek a változtatásnak az elfogadásához, megvalósításához jelentős tudatosságnövelésre és állami támogatásra lesz szükség.Ami mindenképpen tanulságos volt Mádlné Szőnyi Judit hidrogeológus szakember előadásában, hogy valójában nemcsak a „hagyományos”, vagyis a mély geotermiában, de a sekély geotermiában is óriási lehetőségek rejlenek.Gyakorlatilag bármelyik magyar település hasznosíthatna ilyen projektekben, 100-200 méteres fúrásokkal energiát.Ezen a területen Finnországtól tanulhatnánk sokat, ott ugyanis úgy működnek a rendszerek, hogy valójában sokkal rosszabbak az ország adottságai, mint Magyarországon, vagyis ahogy haladunk lefelé, kevésbé melegszik a víz, illetve a kőzet.Akit szakszerűbben is érdekel ez a téma, Mádlné Szőnyi Judit tanulmányban is megírta gondolatait, amelynek már a címe is jó összefoglaló a hazai potenciálról:„Nem lehet mindenhol mindent, de mindenhol lehet valamit.”Úgy tudjuk, hogy mindezzel nagy vonalakban egyetért a kormányzati stratégia is, igaz, a program nagyobbakat lépne, a legfontosabb eleme érezhetően az, hogy távfűtéssel, áramtermeléssel minél több import földgáz legyen kiváltható. A ma még nem publikus, de Steiner Attila államtitkár által is belengetett geotermikus stratégiáról azt hallottuk, hogy a keretet a 2050-re elérendő karbonsemleges gazdaság jelenti. A kormány számításai szerint ma 6 petajoule (PJ)/év az összesített hazai geotermikus energia hasznosulás (ha energia-egyenértékesben számolunk, Magyarország mintegy 200 PJ energiát hasznosít fűtésre, áramra, közlekedésre).Geotermiában az elvi potenciál a mai használatnak a tízszerese, 55-60 PJ/év, a kormány szerint az éves lehetséges növekmény nagyjából 0,5 PJ/év.Olyan köztes adatokról is hallani, hogy 2025-re 8 PJ/év, 2030-ra pedig 12 PJ/év is lehet már a geotermikus energiahasznosítás, illetve van egy olyan álom, hogy akár 1-1,5 milliárd köbméter földgáz kiváltása is lehetséges.Ez politikai döntések és jogszabály változások függvénye lesz, de azt, hogy ehhez pontosan mit fog segíteni a kormányzat, még kevésbé tudjuk. De cél a geotermikus energia kutatásának, kinyerésének és hasznosításának támogatása, egyszerűsített engedélyeztetése is. A befektetőket pedig a kormány több ingyenesen elérhető információ megosztásával, átadásával is segítené, de pénzügyi támogatások is vannak a távlati elképzelésekben. Arról, hogy a földgáz kiváltására mennyire alkalmas a földhő, itt írt a Másfélfok.<h2>A fűtés a legfontosabb</h2>A hazai földhőhasználat mai kulcseleme a hőenergia, vagyis a fűtés. Ez egészen a római korig nyúlik vissza, azóta ismertek a fűtési me ...

# %%
filtered_df = umap_data[(umap_data['dim1'] >= 14)]
indices = filtered_df.index.tolist()
indices
index = 120
print(merged_df['author_primary'][indices[index:index+10]])
print(merged_df['tag_primary'][indices[index:index+10]])
print(merged_df['tag_secondary'][indices[index:index+10]])
print(merged_df['tag_tertary'][indices[index:index+10]])
print(merged_df['tag_quaternary'][indices[index:index+10]])
# Out:
# 15106          Fehér János
# 15379     Brückner Gergely
# 15693            Pál Tamás
# 15752          Fehér János
# 16049        Mizsur András
# 16204        Előd Fruzsina
# 16257            Pál Tamás
# 16491     Brückner Gergely
# 16496    Bakró-Nagy Ferenc
# 16528    Bakró-Nagy Ferenc
# Name: author_primary, dtype: object
# 15106       Sport
# 15379       Sport
# 15693       Sport
# 15752       Sport
# 16049    Gazdaság
# 16204       Sport
# 16257       Sport
# 16491    Gazdaság
# 16496    Gazdaság
# 16528       Sport
# Name: tag_primary, dtype: object
# 15106    Gazdaság
# 15379    Gazdaság
# 15693    Gazdaság
# 15752    Gazdaság
# 16049       Sport
# 16204    Gazdaság
# 16257    Gazdaság
# 16491       Sport
# 16496       Sport
# 16528    Gazdaság
# Name: tag_secondary, dtype: object
# 15106   NaN
# 15379   NaN
# 15693   NaN
# 15752   NaN
# 16049   NaN
# 16204   NaN
# 16257   NaN
# 16491   NaN
# 16496   NaN
# 16528   NaN
# Name: tag_tertary, dtype: float64
# 15106   NaN
# 15379   NaN
# 15693   NaN
# 15752   NaN
# 16049   NaN
# 16204   NaN
# 16257   NaN
# 16491   NaN
# 16496   NaN
# 16528   NaN
# Name: tag_quaternary, dtype: float64
